# %%
Print your name, roll no

# %%
name = "Kavanvanshikumar Chaudhari"
roll_no = 59

print("Name:", name)
print("Roll No:", roll_no)
# Out:
# Name: Kavanvanshikumar Chaudhari
# Roll No: 59

# %% [markdown]
# Write a program to check whether entered frequency isradio frequency or audio frequency.

# %%
f = float(input("Enter frequency in Hz: "))

if f <= 20000:
    print("Audio Frequency (AF)")
else:
    print("Radio Frequency (RF)")
# Out:
# Enter frequency in Hz:  30000
# Radio Frequency (RF)

# %% [markdown]
# Program to display RF bands using if–elif

# %%
f = float(input("Enter frequency in Hz: "))

if 30000 <= f <= 300000:
    print("VLF Band")
elif 300000 < f <= 3000000:
    print("LF Band")
elif 3000000 < f <= 30000000:
    print("MF Band")
elif 30000000 < f <= 300000000:
    print("HF Band")
elif 300000000 < f <= 3000000000:
    print("VHF Band")
else:
    print("UHF / Higher Band")
# Out:
# Enter frequency in Hz:  5000000
# MF Band

# %% [markdown]
#  Program for resistor color code using selection logic

# %%
clr = input("Enter color: ").lower()

if clr == "black":
    print(0)
elif clr == "brown":
    print(1)
elif clr == "red":
    print(2)
elif clr == "orange":
    print(3)
elif clr == "yellow":
    print(4)
elif clr == "green":
    print(5)
elif clr == "blue":
    print(6)
elif clr == "violet":
    print(7)
elif clr == "grey" or clr == "gray":
    print(8)
elif clr == "white":
    print(9)
else:
    print("Invalid color")
# Out:
# Enter color:  blue
# 6

# %% [markdown]
# Write a Python program that checks if the voltage of a battery is greater than 3.7V and prints "Battery is charged" if true.

# %%
voltage = float(input("Enter battery voltage: "))

if voltage > 3.7:
    print("Battery is charged")
else:
    print("Battery is not charged")
# Out:
# Enter battery voltage:  3.0
# Battery is not charged

# %% [markdown]
# Write a Python program that checks if a resistor value is within a tolerance range (e.g., 5% tolerance for a 100Ω resistor) and prints whether it is within tolerance or not.

# %%
value = float(input("Enter measured resistance: "))

min_val = 100 - (5/100)*100
max_val = 100 + (5/100)*100

if min_val <= value <= max_val:
    print("Resistor is within tolerance")
else:
    print("Resistor is out of tolerance")
# Out:
# Enter measured resistance:  300
# Resistor is out of tolerance

# %% [raw]
# SImple if

# %%
f = float(input("Frequency: "))
if f < 20000:
    print("AF")
else:
    print("RF")
# Out:
# Frequency:  250000
# RF

# %% [raw]
# clr = input("Color: ")
#
# if clr = "red":
#
#     print(2)

# %%
clr = input("Color: ")

if clr == "red":

    print(2)
# Out:
# Color:  red
# 2

# %% [markdown]
# Q1: Check if a number is positive
#
# IF number > 0 THEN
#
#     PRINT "Positive"
#
# ENDIF

# %%
number = float(input("Enter a number: "))
if number > 0:
    print("Positive")
# Out:
# Enter a number:  6
# Positive

# %%
Q2: Check if age is eligible to vote
IF age >= 18 THEN
    PRINT "Eligible to vote"
ENDIF

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Eligible to vote")
# Out:
# Enter your age:  20
# Eligible to vote

# %%
Q3: Check if temperature is high
IF temperature > 40 THEN
    PRINT "High Temperature"
ENDIF

# %%
temperature = float(input("Enter temperature: "))
if temperature > 40:
    print("High Temperature")
# Out:
# Enter temperature:  43
# High Temperature

# %%
Q4: Check if number is even
IF number MOD 2 = 0 THEN
    PRINT "Even Number"
ENDIF

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("Even Number")
# Out:
# Enter a number:  8
# Even Number

# %%
Q5: Check if password is correct
IF password = "admin" THEN
    PRINT "Access Granted"
ENDIF

# %%
password = input("Enter password: ")
if password == "admin":
    print("Access Granted")
# Out:
# Enter password:  admin
# Access Granted

# %%
2️⃣ IF–ELSE

# %%
Q1: Check if a number is positive or negative
IF number >= 0 THEN
    PRINT "Positive"
ELSE
    PRINT "Negative"
ENDIF

# %%
number = float(input("Enter a number: "))
if number >= 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Enter a number:  -1
# Negative

# %%
Q2: Check pass or fail
IF marks >= 40 THEN
    PRINT "Pass"
ELSE
    PRINT "Fail"
ENDIF

# %%
marks = float(input("Enter marks: "))
if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  60
# Pass

# %%
Q3: Check even or odd
IF number MOD 2 = 0 THEN
    PRINT "Even"
ELSE
    PRINT "Odd"
ENDIF

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  5
# Odd

# %%
Q4: Check eligible for driving
IF age >= 18 THEN
    PRINT "Eligible"
ELSE
    PRINT "Not Eligible"
ENDIF

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter your age:  12
# Not Eligible

# %%
Q5: Check login status
IF login = TRUE THEN
    PRINT "Welcome"
ELSE
    PRINT "Invalid Login"
ENDIF

# %%
login = input("Are you logged in? (True/False): ").lower() == 'true'
if login == True:
    print("Welcome")
else:
    print("Invalid Login")
# Out:
# Are you logged in? (True/False):  True
# Welcome

# %%
IF–ELIF–ELSE

# %%
Q1: Grade based on marks
IF marks >= 75 THEN
    PRINT "A"
ELIF marks >= 60 THEN
    PRINT "B"
ELSE
    PRINT "C"
ENDIF

# %%
marks = float(input("Enter marks: "))
if marks >= 75:
    print("A")
elif marks >= 60:
    print("B")
else:
    print("C")
# Out:
# Enter marks:  89
# A

# %%
Q2: Number sign
IF number > 0 THEN
    PRINT "Positive"
ELIF number = 0 THEN
    PRINT "Zero"
ELSE
    PRINT "Negative"
ENDIF

# %%
number = float(input("Enter a number: "))
if number > 0:
    print("Positive")
elif number == 0:
    print("Zero")
else:
    print("Negative")

# %%
Q3: Temperature level
IF temp > 40 THEN
    PRINT "High"
ELIF temp > 20 THEN
    PRINT "Normal"
ELSE
    PRINT "Low"
ENDIF

# %%
temp = float(input("Enter temperature: "))
if temp > 40:
    print("High")
elif temp > 20:
    print("Normal")
else:
    print("Low")
# Out:
# Enter temperature:  56
# High

# %%
Q4: Day type
IF day = "Sunday" THEN
    PRINT "Holiday"
ELIF day = "Saturday" THEN
    PRINT "Half Day"
ELSE
    PRINT "Working Day"
ENDIF

# %%
day = input("Enter the day (e.g., Sunday): ")
if day == "Sunday":
    print("Holiday")
elif day == "Saturday":
    print("Half Day")
else:
    print("Working Day")
# Out:
# Enter the day (e.g., Sunday):  Sunday
# Holiday

# %%
Q5: Speed check
IF speed > 80 THEN
    PRINT "Overspeed"
ELIF speed > 40 THEN
    PRINT "Normal"
ELSE
    PRINT "Slow"
ENDIF

# %%
speed = float(input("Enter speed: "))
if speed > 80:
    print("Overspeed")
elif speed > 40:
    print("Normal")
else:
    print("Slow")
# Out:
# Enter speed:  90
# Overspeed

# %%
NESTED IF–ELSE

# %%
Q1: Largest of two numbers
IF a > b THEN
    PRINT "A is largest"
ELSE
    IF b > a THEN
        PRINT "B is largest"
    ELSE
        PRINT "Both equal"
    ENDIF
ENDIF

# %%
a = float(input("Enter number a: "))
b = float(input("Enter number b: "))
if a > b:
    print("A is largest")
else:
    if b > a:
        print("B is largest")
    else:
        print("Both equal")
# Out:
# Enter number a:  45
# Enter number b:  75
# B is largest

# %%
Q2: Result with distinction
IF marks >= 40 THEN
    IF marks >= 75 THEN
        PRINT "Distinction"
    ELSE
        PRINT "Pass"
    ENDIF
ELSE
    PRINT "Fail"
ENDIF

# %%
marks = float(input("Enter marks: "))
if marks >= 40:
    if marks >= 75:
        print("Distinction")
    else:
        print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  89
# Distinction

# %%
Q3: Login and role check
IF login = TRUE THEN
    IF role = "Admin" THEN
        PRINT "Admin Access"
    ELSE
        PRINT "User Access"
    ENDIF
ELSE
    PRINT "Login Failed"
ENDIF

# %%
login = input("Are you logged in? (True/False): ").lower() == 'true'
role = input("Enter your role: ")

if login == True:
    if role == "Admin":
        print("Admin Access")
    else:
        print("User Access")
else:
    print("Login Failed")
# Out:
# Are you logged in? (True/False):  False
# Enter your role:  Admin
# Login Failed

# %%
Q4: Weather advice
IF raining = TRUE THEN
    IF umbrella = TRUE THEN
        PRINT "Go Outside"
    ELSE
        PRINT "Stay Inside"
    ENDIF
ELSE
    PRINT "Enjoy the Day"
ENDIF

# %%
is_raining = input("Is it raining? (True/False): ").lower() == 'true'
has_umbrella = input("Do you have an umbrella? (True/False): ").lower() == 'true'

if is_raining and has_umbrella:
    print("Go Outside")
elif is_raining and not has_umbrella:
    print("Stay Inside")
else:
    print("Enjoy the Day")
# Out:
# Is it raining? (True/False):  true
# Do you have an umbrella? (True/False):  false
# Stay Inside

# %%
Q5: Exam eligibility
IF attendance >= 75 THEN
    IF fees_paid = TRUE THEN
        PRINT "Eligible for Exam"
    ELSE
        PRINT "Pay Fees"
    ENDIF
ELSE
    PRINT "Low Attendance"
ENDIF

# %%
attendance = float(input("Enter attendance percentage: "))
fees_paid = input("Have fees been paid? (True/False): ").lower() == 'true'

if attendance >= 75:
    if fees_paid == True:
        print("Eligible for Exam")
    else:
        print("Pay Fees")
else:
    print("Low Attendance")
# Out:
# Enter attendance percentage:  56
# Have fees been paid? (True/False):  true
# Low Attendance
